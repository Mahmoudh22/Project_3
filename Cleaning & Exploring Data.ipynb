# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('/Users/mahmoud/Documents/Project_3/data.csv')

df.head()
# Out:
#    Unnamed: 0 state  account length  area code phone number  \
# 0        2682    DC              55        510     354-5058
# 1        3304    IL              71        510     330-7137
# 2         757    UT             112        415     358-5953
# 3        2402    NY              77        415     388-9285
# 4         792    NV              69        510     397-6789
#
#   international plan voice mail plan  number vmail messages  \
# 0                yes              no                      0
# 1                yes              no                      0
# 2                 no              no                      0
# 3                 no             yes                     33
# 4                yes             yes                     33
#
#    total day minutes  total day calls  ...  total eve calls  total eve charge  \
# 0              106.1               77  ...              100             10.50
# 1              186.1              114  ...              140             16.88
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2999 entries, 0 to 2998
# Data columns (total 22 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Unnamed: 0              2999 non-null   int64
#  1   state                   2999 non-null   object
#  2   account length          2999 non-null   int64
#  3   area code               2999 non-null   int64
#  4   phone number            2999 non-null   object
#  5   international plan      2999 non-null   object
#  6   voice mail plan         2999 non-null   object
#  7   number vmail messages   2999 non-null   int64
#  8   total day minutes       2999 non-null   float64
#  9   total day calls         2999 non-null   int64
#  10  total day charge        2999 non-null   float64
#  11  total eve minutes       2999 non-null   float64
#  12  total eve calls         2999 non-null   int64
#  13  total eve charge        2999 non-null   float64
# ...

# %%
# confirming there is no null values 
df.isna().sum()
# Out:
# Unnamed: 0                0
# state                     0
# account length            0
# area code                 0
# phone number              0
# international plan        0
# voice mail plan           0
# number vmail messages     0
# total day minutes         0
# total day calls           0
# total day charge          0
# total eve minutes         0
# total eve calls           0
# total eve charge          0
# total night minutes       0
# total night calls         0
# total night charge        0
# total intl minutes        0
# total intl calls          0
# total intl charge         0
# customer service calls    0
# churn                     0
# dtype: int64

# %%
# Any duplicates?
df.duplicated().sum()
# Out:
# 0

# %%
df.tail()
# Out:
#       Unnamed: 0 state  account length  area code phone number  \
# 2994        2763    NC             116        408     338-7527
# 2995         905    WV             161        415     418-9036
# 2996        1096    RI              93        415     406-5584
# 2997         235    MN             139        510     374-9107
# 2998        1061    ND             132        415     336-4281
#
#      international plan voice mail plan  number vmail messages  \
# 2994                 no             yes                     19
# 2995                 no              no                      0
# 2996                 no              no                      0
# 2997                 no              no                      0
# 2998                 no             yes                     31
#
#       total day minutes  total day calls  ...  total eve calls  \
# 2994              155.7              104  ...              118
# 2995              191.9              113  ...               87
# ...

# %%
df.describe()
# Out:
#         Unnamed: 0  account length    area code  number vmail messages  \
# count  2999.000000     2999.000000  2999.000000            2999.000000
# mean   1666.911304      100.784261   437.164722               8.072357
# std     958.438833       39.819788    42.389450              13.721684
# min       0.000000        1.000000   408.000000               0.000000
# 25%     839.000000       74.000000   408.000000               0.000000
# 50%    1672.000000      100.000000   415.000000               0.000000
# 75%    2493.500000      127.000000   510.000000              19.000000
# max    3332.000000      243.000000   510.000000              51.000000
#
#        total day minutes  total day calls  total day charge  \
# count        2999.000000      2999.000000       2999.000000
# mean          179.538980       100.401134         30.522154
# std            54.427739        20.117802          9.252662
# min             0.000000         0.000000          0.000000
# ...

# %%
# value counts of churn (our target)
df['churn'].value_counts()
# Out:
# False    2569
# True      430
# Name: churn, dtype: int64

# %%
# imbalance which will have to be dealt with; find the % 
df['churn'].value_counts(normalize=True)
# Out:
# False    0.856619
# True     0.143381
# Name: churn, dtype: float64

# %% [markdown]
# # Build a classifier to predict whether a customer will ("soon") stop doing business with SyriaTel, a telecommunications company

# %% [markdown]
# - Some questions:
# 1. Are there certain areas or states where it is more likely to have a customer churn?
# 2. Is there a correlation between usage of service and churning?

# %%
# first split the data to avoide data leakage
# our test split is using 10% of df data
df_train, df_test = train_test_split(df, test_size=.1, random_state=1)

# %%
# having this trained data in a dataset saved
df_train.to_csv('/Users/mahmoud/Documents/Project_3_SyriaTel_Customer_Churn/train.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-17-60884088007e> in <module>
#       1 # having this trained data in a dataset saved
# ----> 2 df_train.to_csv('/Users/mahmoud/Documents/Project_3_SyriaTel_Customer_Churn/train.csv')
#
# ~/anaconda3/envs/learn-env/lib/python3.8/site-packages/pandas/core/generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal, errors)
#    3168             decimal=decimal,
#    3169         )
# -> 3170         formatter.save()
#    3171
#    3172         if path_or_buf is None:
#
# ~/anaconda3/envs/learn-env/lib/python3.8/site-packages/pandas/io/formats/csvs.py in save(self)
#     183             close = False
#     184         else:
# ...

# %%
# having this test data is a dataset saved
df_test.to_csv('/Users/mahmoud/Documents/Project_3_SyriaTel_Customer_Churn/test.csv')

# %%
df.to_excel('/Users/mahmoud/Documents/Project_3/train.xlsx', index=False)
